# %% [markdown]
# <a href="https://colab.research.google.com/github/Hongjaaa/OSMnx-Practice/blob/main/OSMnx_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install osmnx
# Out:
# Requirement already satisfied: osmnx in /usr/local/lib/python3.7/dist-packages (1.1.1)
# Requirement already satisfied: requests>=2.25 in /usr/local/lib/python3.7/dist-packages (from osmnx) (2.26.0)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.7/dist-packages (from osmnx) (3.4.3)
# Requirement already satisfied: geopandas>=0.9 in /usr/local/lib/python3.7/dist-packages (from osmnx) (0.10.2)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.1.5)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.7/dist-packages (from osmnx) (2.6.3)
# Requirement already satisfied: Rtree>=0.9 in /usr/local/lib/python3.7/dist-packages (from osmnx) (0.9.7)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.19.5)
# Requirement already satisfied: Shapely>=1.7 in /usr/local/lib/python3.7/dist-packages (from osmnx) (1.8.0)
# Requirement already satisfied: pyproj>=2.6 in /usr/local/lib/python3.7/dist-packages (from osmnx) (3.2.1)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas>=0.9->osmnx) (1.8.20)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (1.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (57.4.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (21.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (2021.10.8)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (0.7.2)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (1.15.0)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.9->osmnx) (2.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx) (7.1.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->osmnx) (2018.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx) (2.0.7)

# %%
import osmnx as ox, networkx as nx, geopandas as gpd, matplotlib.pyplot as plt
from shapely.geometry import Point, Polygon, LineString
from descartes import PolygonPatch
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors
ox.config(use_cache=True, log_console=True)
ox.__version__
# Out:
# '1.1.1'

# %%
# www.openstreetmap.org에서 검색 결과가 city-state-country 단위로 나와야 함 - '마포구, 서울, 대한민국'
G = ox.graph_from_place('성북구, 서울, 대한민국', network_type='drive', simplify=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:

# %%
# get a graph for some city
# www.openstreetmap.org에서 검색 결과가 city-state-country 단위로 나와야 함 

G = ox.graph_from_place('성북구, 서울, 대한민국', network_type='drive', simplify=False)
fig, ax = ox.plot_graph(G,node_size=0,edge_linewidth=0.5)
# Out:
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:

# %%
G_proj = ox.project_graph(G)

# %%
orig = ox.get_nearest_node(G, (37.608474, 126.999593)) #내부순환로 
dest = ox.get_nearest_node(G, (37.604646, 127.02879))
# Out:
# /usr/local/lib/python3.7/dist-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)
# /usr/local/lib/python3.7/dist-packages/osmnx/distance.py:356: UserWarning: The `get_nearest_node` function has been deprecated and will be removed in a future release. Use the more efficient `distance.nearest_nodes` instead.
#   warnings.warn(msg)

# %%
# 거리 기반 최단경로 1개 탐색
route = ox.shortest_path(G, orig, dest, weight='length')
fig1_1, ax = ox.plot_graph_route(G, route, route_color='b', route_linewidth=6, node_size=0.5)

# %%
pip install prettymaps
# Out:
# Collecting prettymaps
#   Downloading prettymaps-0.1.3-py3-none-any.whl (22 kB)
# Collecting osmnx==1.0.1
#   Downloading osmnx-1.0.1-py2.py3-none-any.whl (87 kB)
#      |████████████████████████████████| 87 kB 4.8 MB/s
# Requirement already satisfied: tabulate==0.8.9 in /usr/local/lib/python3.7/dist-packages (from prettymaps) (0.8.9)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps) (1.1.5)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps) (1.19.5)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps) (3.4.3)
# Requirement already satisfied: requests>=2.25 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps) (2.26.0)
# Requirement already satisfied: Shapely>=1.7 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps) (1.8.0)
# Requirement already satisfied: descartes>=1.1 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps) (1.1.0)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps) (2.6.3)
# Requirement already satisfied: geopandas>=0.8 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps) (0.10.2)
# Requirement already satisfied: Rtree>=0.9 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps) (0.9.7)
# Requirement already satisfied: pyproj>=2.6 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps) (3.2.1)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas>=0.8->osmnx==1.0.1->prettymaps) (1.8.20)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps) (2.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps) (57.4.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps) (21.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps) (1.1.1)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps) (7.1.2)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps) (0.7.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps) (2021.10.8)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps) (1.15.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps) (7.1.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->osmnx==1.0.1->prettymaps) (2018.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx==1.0.1->prettymaps) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx==1.0.1->prettymaps) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx==1.0.1->prettymaps) (2.10)
# Installing collected packages: osmnx, prettymaps
#   Attempting uninstall: osmnx
#     Found existing installation: osmnx 1.1.1
#     Uninstalling osmnx-1.1.1:
#       Successfully uninstalled osmnx-1.1.1
# Successfully installed osmnx-1.0.1 prettymaps-0.1.3

# %%
# !pip install git+https://github.com/abey79/vsketch#egg=vsketch
# !pip install git+https://github.com/marceloprates/prettymaps.git

# !mkdir ../prints
# !mkdir ../assets
# !mkdir ../assets/Permanent_Marker/
# !wget -O ../assets/Permanent_Marker/PermanentMarker-Regular.ttf https://github.com/marceloprates/prettymaps/raw/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf
# Out:
# Collecting vsketch
#   Cloning https://github.com/abey79/vsketch to /tmp/pip-install-b9ldhxuq/vsketch_e973ba175a7344e69533afd5d37eabb5
#   Running command git clone -q https://github.com/abey79/vsketch /tmp/pip-install-b9ldhxuq/vsketch_e973ba175a7344e69533afd5d37eabb5
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting jupyterlab-code-formatter<2.0.0,>=1.4.1
#   Downloading jupyterlab_code_formatter-1.4.10-py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 7.1 MB/s
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.3 in /usr/local/lib/python3.7/dist-packages (from vsketch) (3.4.3)
# Requirement already satisfied: multiprocess<0.71.0,>=0.70.11 in /usr/local/lib/python3.7/dist-packages (from vsketch) (0.70.12.2)
# Collecting colorama<0.5.0,>=0.4.4
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting vpype[all]==1.7.0
#   Downloading vpype-1.7.0-py3-none-any.whl (505 kB)
#      |████████████████████████████████| 505 kB 36.7 MB/s
# Requirement already satisfied: Shapely[vectorized]<2.0.0,>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from vsketch) (1.8.0)
# Collecting pnoise<0.2.0,>=0.1.0
#   Downloading pnoise-0.1.0-py3-none-any.whl (13 kB)
# Collecting bezier>=2021.2.12
#   Downloading bezier-2021.2.12-cp37-cp37m-manylinux2010_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 43.7 MB/s
# Collecting cookiecutter<2.0.0,>=1.7.2
#   Downloading cookiecutter-1.7.3-py2.py3-none-any.whl (34 kB)
# Collecting numpy<2.0.0,>=1.20.1
#   Downloading numpy-1.21.4-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 61 kB/s
# Collecting PySide2<6.0.0,>=5.15.2
#   Downloading PySide2-5.15.2-5.15.2-cp35.cp36.cp37.cp38.cp39-abi3-manylinux1_x86_64.whl (164.3 MB)
#      |████████████████████████████████| 164.3 MB 2.6 kB/s
# Collecting watchgod<0.8,>=0.7
#   Downloading watchgod-0.7-py3-none-any.whl (11 kB)
# Collecting qasync<0.16.0,>=0.15.0
#   Downloading qasync-0.15.0-py3-none-any.whl (13 kB)
# Collecting Shapely[vectorized]<2.0.0,>=1.7.1
#   Downloading Shapely-1.7.1-cp37-cp37m-manylinux1_x86_64.whl (1.0 MB)
#      |████████████████████████████████| 1.0 MB 60.9 MB/s
# Collecting svgwrite<1.5,>=1.4
#   Downloading svgwrite-1.4.1-py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 5.5 MB/s
# Requirement already satisfied: click-plugins<1.2.0,>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from vpype[all]==1.7.0->vsketch) (1.1.1)
# Collecting click<8.1.0,>=8.0.1
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 5.7 MB/s
# Requirement already satisfied: attrs<21.3.0,>=21.2.0 in /usr/local/lib/python3.7/dist-packages (from vpype[all]==1.7.0->vsketch) (21.2.0)
# Collecting scipy<2.0,>=1.6
#   Downloading scipy-1.7.2-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.2 MB)
#      |████████████████████████████████| 38.2 MB 26 kB/s
# Requirement already satisfied: cachetools<5.0.0,>=4.2.2 in /usr/local/lib/python3.7/dist-packages (from vpype[all]==1.7.0->vsketch) (4.2.4)
# Collecting svgelements==1.5.4
#   Downloading svgelements-1.5.4-py2.py3-none-any.whl (109 kB)
#      |████████████████████████████████| 109 kB 73.5 MB/s
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from vpype[all]==1.7.0->vsketch) (0.10.2)
# Collecting setuptools<52.0.0,>=51.0.0
#   Downloading setuptools-51.3.3-py3-none-any.whl (786 kB)
#      |████████████████████████████████| 786 kB 47.1 MB/s
# Collecting Pillow<9.0.0,>=8.1.0
#   Downloading Pillow-8.4.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      |████████████████████████████████| 3.1 MB 39.3 MB/s
# Collecting glcontext>=2.3.2
#   Downloading glcontext-2.3.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (64 kB)
#      |████████████████████████████████| 64 kB 3.0 MB/s
# Collecting moderngl<6.0.0,>=5.6.2
#   Downloading moderngl-5.6.4-cp37-cp37m-manylinux1_x86_64.whl (670 kB)
#      |████████████████████████████████| 670 kB 42.3 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click<8.1.0,>=8.0.1->vpype[all]==1.7.0->vsketch) (4.8.2)
# Collecting poyo>=0.5.0
#   Downloading poyo-0.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.7/dist-packages (from cookiecutter<2.0.0,>=1.7.2->vsketch) (2.26.0)
# Collecting binaryornot>=0.4.4
#   Downloading binaryornot-0.4.4-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from cookiecutter<2.0.0,>=1.7.2->vsketch) (1.15.0)
# Requirement already satisfied: Jinja2<4.0.0,>=2.7 in /usr/local/lib/python3.7/dist-packages (from cookiecutter<2.0.0,>=1.7.2->vsketch) (2.11.3)
# Collecting jinja2-time>=0.2.0
#   Downloading jinja2_time-0.2.0-py2.py3-none-any.whl (6.4 kB)
# Requirement already satisfied: python-slugify>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from cookiecutter<2.0.0,>=1.7.2->vsketch) (5.0.2)
# Requirement already satisfied: chardet>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from binaryornot>=0.4.4->cookiecutter<2.0.0,>=1.7.2->vsketch) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<4.0.0,>=2.7->cookiecutter<2.0.0,>=1.7.2->vsketch) (2.0.1)
# Collecting arrow
#   Downloading arrow-1.2.1-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.0 MB/s
# Collecting jupyterlab~=3.0
#   Downloading jupyterlab-3.2.3-py3-none-any.whl (8.6 MB)
#      |████████████████████████████████| 8.6 MB 69.3 MB/s
# Collecting jupyter-server~=1.4
#   Downloading jupyter_server-1.11.2-py3-none-any.whl (394 kB)
#      |████████████████████████████████| 394 kB 56.8 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (21.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.7/dist-packages (from jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (5.5.0)
# Collecting tornado>=6.1.0
#   Downloading tornado-6.1-cp37-cp37m-manylinux2010_x86_64.whl (428 kB)
#      |████████████████████████████████| 428 kB 54.7 MB/s
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (4.9.1)
# Collecting nbclassic~=0.2
#   Downloading nbclassic-0.3.4-py3-none-any.whl (25 kB)
# Collecting jupyterlab-server~=2.3
#   Downloading jupyterlab_server-2.8.2-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 5.3 MB/s
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.3.4-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 7.0 MB/s
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (22.3.0)
# Collecting jupyter-client>=6.1.1
#   Downloading jupyter_client-7.0.6-py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 55.4 MB/s
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (5.1.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.12.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.2.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (5.1.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (21.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (5.6.1)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.7/dist-packages (from jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.12.1)
# Collecting websocket-client
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
#      |████████████████████████████████| 52 kB 1.4 MB/s
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (2.10)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from anyio<4,>=3.1.0->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (3.10.0.2)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.1->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (2.8.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.1->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.5.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.7/dist-packages (from jupyter-client>=6.1.1->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.3)
# Collecting jsonschema>=3.0.1
#   Downloading jsonschema-4.2.1-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 7.9 MB/s
# Requirement already satisfied: babel in /usr/local/lib/python3.7/dist-packages (from jupyterlab-server~=2.3->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (2.9.1)
# Collecting json5
#   Downloading json5-0.9.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (5.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.18.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=3.0.1->jupyterlab-server~=2.3->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (3.6.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib<4.0.0,>=3.3.3->vsketch) (2.4.7)
# Requirement already satisfied: dill>=0.3.4 in /usr/local/lib/python3.7/dist-packages (from multiprocess<0.71.0,>=0.70.11->vsketch) (0.3.4)
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.7/dist-packages (from nbclassic~=0.2->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (5.3.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.7/dist-packages (from notebook<7->nbclassic~=0.2->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (4.10.1)
# Collecting shiboken2==5.15.2
#   Downloading shiboken2-5.15.2-5.15.2-cp35.cp36.cp37.cp38.cp39-abi3-manylinux1_x86_64.whl (956 kB)
#      |████████████████████████████████| 956 kB 40.2 MB/s
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify>=4.0.0->cookiecutter<2.0.0,>=1.7.2->vsketch) (1.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->cookiecutter<2.0.0,>=1.7.2->vsketch) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->cookiecutter<2.0.0,>=1.7.2->vsketch) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.23.0->cookiecutter<2.0.0,>=1.7.2->vsketch) (1.24.3)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.3->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0.0->argon2-cffi->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (2.21)
# Requirement already satisfied: pytz>=2015.7 in /usr/local/lib/python3.7/dist-packages (from babel->jupyterlab-server~=2.3->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (2018.9)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.0.18)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (4.8.0)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.7.5)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (4.4.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.2.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.8.4)
# Requirement already satisfied: bleach in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (4.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (1.5.0)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach->nbconvert->jupyter-server~=1.4->jupyterlab~=3.0->jupyterlab-code-formatter<2.0.0,>=1.4.1->vsketch) (0.5.1)
# Building wheels for collected packages: vsketch
#   Building wheel for vsketch (PEP 517) ... done
#   Created wheel for vsketch: filename=vsketch-1.0.0a0-py3-none-any.whl size=57164 sha256=fbc4c65fa6791730174870af8d5c25e2166c4145019dc2561a6fa2ae1dfe391e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6_lb83z0/wheels/72/4c/ec/5cb144efa9493c616569d1d60c776721cdff8977ab91376d97
# Successfully built vsketch
# Installing collected packages: tornado, setuptools, jsonschema, sniffio, jupyter-client, websocket-client, anyio, Shapely, numpy, jupyter-server, json5, click, svgwrite, svgelements, shiboken2, scipy, pnoise, Pillow, nbclassic, jupyterlab-server, glcontext, arrow, vpype, PySide2, poyo, moderngl, jupyterlab, jinja2-time, binaryornot, watchgod, qasync, jupyterlab-code-formatter, cookiecutter, colorama, bezier, vsketch
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 57.4.0
#     Uninstalling setuptools-57.4.0:
#       Successfully uninstalled setuptools-57.4.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 2.6.0
#     Uninstalling jsonschema-2.6.0:
#       Successfully uninstalled jsonschema-2.6.0
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter-client 5.3.5
#     Uninstalling jupyter-client-5.3.5:
#       Successfully uninstalled jupyter-client-5.3.5
#   Attempting uninstall: Shapely
#     Found existing installation: Shapely 1.8.0
#     Uninstalling Shapely-1.8.0:
#       Successfully uninstalled Shapely-1.8.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.1.2
#     Uninstalling Pillow-7.1.2:
#       Successfully uninstalled Pillow-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.26.0 which is incompatible.
# google-colab 1.0.0 requires tornado~=5.1.0; python_version >= "3.0", but you have tornado 6.1 which is incompatible.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.0.3 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed Pillow-8.4.0 PySide2-5.15.2 Shapely-1.7.1 anyio-3.3.4 arrow-1.2.1 bezier-2021.2.12 binaryornot-0.4.4 click-8.0.3 colorama-0.4.4 cookiecutter-1.7.3 glcontext-2.3.4 jinja2-time-0.2.0 json5-0.9.6 jsonschema-4.2.1 jupyter-client-7.0.6 jupyter-server-1.11.2 jupyterlab-3.2.3 jupyterlab-code-formatter-1.4.10 jupyterlab-server-2.8.2 moderngl-5.6.4 nbclassic-0.3.4 numpy-1.21.4 pnoise-0.1.0 poyo-0.5.0 qasync-0.15.0 scipy-1.7.2 setuptools-51.3.3 shiboken2-5.15.2 sniffio-1.2.0 svgelements-1.5.4 svgwrite-1.4.1 tornado-6.1 vpype-1.7.0 vsketch-1.0.0a0 watchgod-0.7 websocket-client-1.2.1
# Collecting git+https://github.com/marceloprates/prettymaps.git
#   Cloning https://github.com/marceloprates/prettymaps.git to /tmp/pip-req-build-3gae_yke
#   Running command git clone -q https://github.com/marceloprates/prettymaps.git /tmp/pip-req-build-3gae_yke
# Requirement already satisfied: osmnx==1.0.1 in /usr/local/lib/python3.7/dist-packages (from prettymaps==0.1.3) (1.0.1)
# Requirement already satisfied: tabulate==0.8.9 in /usr/local/lib/python3.7/dist-packages (from prettymaps==0.1.3) (0.8.9)
# Requirement already satisfied: pyproj>=2.6 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps==0.1.3) (3.2.1)
# Requirement already satisfied: numpy>=1.19 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.21.4)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.1.5)
# Requirement already satisfied: descartes>=1.1 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.1.0)
# Requirement already satisfied: networkx>=2.5 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps==0.1.3) (2.6.3)
# Requirement already satisfied: Shapely>=1.7 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps==0.1.3) (1.7.1)
# Requirement already satisfied: requests>=2.25 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps==0.1.3) (2.26.0)
# Requirement already satisfied: Rtree>=0.9 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps==0.1.3) (0.9.7)
# Requirement already satisfied: matplotlib>=3.3 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps==0.1.3) (3.4.3)
# Requirement already satisfied: geopandas>=0.8 in /usr/local/lib/python3.7/dist-packages (from osmnx==1.0.1->prettymaps==0.1.3) (0.10.2)
# Requirement already satisfied: fiona>=1.8 in /usr/local/lib/python3.7/dist-packages (from geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (1.8.20)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (51.3.3)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (8.0.3)
# Requirement already satisfied: munch in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (2.5.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (0.7.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (2021.10.8)
# Requirement already satisfied: six>=1.7 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (1.15.0)
# Requirement already satisfied: attrs>=17 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (21.2.0)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.7/dist-packages (from fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (1.1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from click>=4.0->fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (4.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib>=3.3->osmnx==1.0.1->prettymaps==0.1.3) (0.11.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1->osmnx==1.0.1->prettymaps==0.1.3) (2018.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==0.1.3) (2.10)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==0.1.3) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.25->osmnx==1.0.1->prettymaps==0.1.3) (1.24.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->click>=4.0->fiona>=1.8->geopandas>=0.8->osmnx==1.0.1->prettymaps==0.1.3) (3.6.0)
# --2021-11-12 05:28:51--  https://github.com/marceloprates/prettymaps/raw/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/marceloprates/prettymaps/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf [following]
# --2021-11-12 05:28:51--  https://raw.githubusercontent.com/marceloprates/prettymaps/main/assets/Permanent_Marker/PermanentMarker-Regular.ttf
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 73620 (72K) [application/octet-stream]
# Saving to: ‘../assets/Permanent_Marker/PermanentMarker-Regular.ttf’
#
# ../assets/Permanent 100%[===================>]  71.89K  --.-KB/s    in 0.002s
#
# 2021-11-12 05:28:52 (33.7 MB/s) - ‘../assets/Permanent_Marker/PermanentMarker-Regular.ttf’ saved [73620/73620]

# %%
# Style parameters
palette = ['#433633', '#FF5E5B']
background_c = '#F2F4CB'
dilate = 100

# Setup figure
fig, ax = plt.subplots(figsize = (10, 10), constrained_layout = True)

# Plot
layers = plot(
    (37.5894118,127.0168327), radius = 5000,
    ax = ax,
    layers = {
        'perimeter': {'circle': False, 'dilate': dilate},
        'streets': {
            'width': {
                'primary': 5,
                'secondary': 4,
                'tertiary': 3,
                'residential': 2,
                'footway': 1,
            },
            'circle': False,
            'dilate': dilate
        },
        'building': {
            'tags': {'building': True},
            'union': False,
            'circle': False,
            'dilate': dilate
        },
        'green': {
            'tags': {
                'landuse': ['grass', 'village_green'],
                'leisure': 'park'
            },
            'circle': False,
            'dilate': dilate
        },
    },
    drawing_kwargs = {
        'background': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'hatch': 'ooo...', 'zorder': -1},
        'perimeter': {'fill': False, 'lw': 0, 'zorder': 0},
        'green': {'fc': '#8BB174', 'ec': '#2F3737', 'hatch_c': '#A7C497', 'hatch': 'ooo...', 'lw': 1, 'zorder': 1},
        'water': {'fc': '#a8e1e6', 'ec': '#2F3737', 'hatch_c': '#9bc3d4', 'hatch': 'ooo...', 'lw': 1, 'zorder': 3},
        'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 4},
        'building': {'palette': palette, 'ec': '#2F3737', 'lw': .5, 'zorder': 5},
    },
    osm_credit = {'x': .02, 'y': .01, 'color': '#2F3737'}
)

# Set bounds
xmin, ymin, xmax, ymax = layers['perimeter'].bounds
dx, dy = xmax-xmin, ymax-ymin
ax.set_xlim(xmin-.06*dx, xmax+.06*dx)
ax.set_ylim(ymin-.06*dy, ymax+.06*dy)

# Draw left text
ax.text(
    xmin-.06*dx, ymin+.5*dy,
    'Seoul, Korea',
    color = '#2F3737',
    rotation = 90,
    fontproperties = fm.FontProperties(fname = '../assets/Permanent_Marker/PermanentMarker-Regular.ttf', size = 35),
)
# Draw top text
ax.text(
    xmax-.35*dx, ymax+.02*dy,
    "41° 23′ N, 2° 11′ E",
    color = '#2F3737',
    fontproperties = fm.FontProperties(fname = '../assets/Permanent_Marker/PermanentMarker-Regular.ttf', size = 20),
)

#plt.savefig('../prints/barcelona.png')
#plt.savefig('../prints/barcelona.svg')
# Out:
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /usr/local/lib/python3.7/dist-packages/prettymaps/fetch.py:318: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for lines in streets[
# /usr/local/lib/python3.7/dist-packages/prettymaps/fetch.py:318: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for lines in streets[
# /usr/local/lib/python3.7/dist-packages/prettymaps/fetch.py:318: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for lines in streets[
# /usr/local/lib/python3.7/dist-packages/prettymaps/fetch.py:318: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for lines in streets[
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /usr/local/lib/python3.7/dist-packages/osmnx/geometries.py:816: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   Parameters
# /usr/local/lib/python3.7/dist-packages/osmnx/geometries.py:816: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   Parameters
# /usr/local/lib/python3.7/dist-packages/osmnx/geometries.py:805: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   )
# /usr/local/lib/python3.7/dist-packages/osmnx/geometries.py:805: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   )
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /usr/local/lib/python3.7/dist-packages/prettymaps/fetch.py:222: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   multipolys = reduce(lambda x,y: x+y, [list(x) for x in multipolys]) if len(multipolys) > 0 else []
# /usr/local/lib/python3.7/dist-packages/prettymaps/fetch.py:222: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   multipolys = reduce(lambda x,y: x+y, [list(x) for x in multipolys]) if len(multipolys) > 0 else []
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:335: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for polygon in geometry:
# /usr/local/lib/python3.7/dist-packages/osmnx/geometries.py:816: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   Parameters
# /usr/local/lib/python3.7/dist-packages/osmnx/geometries.py:816: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   Parameters
# /usr/local/lib/python3.7/dist-packages/osmnx/utils_geo.py:426: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for poly in multipoly:
# /usr/local/lib/python3.7/dist-packages/prettymaps/fetch.py:222: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   multipolys = reduce(lambda x,y: x+y, [list(x) for x in multipolys]) if len(multipolys) > 0 else []
# /usr/local/lib/python3.7/dist-packages/prettymaps/fetch.py:222: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   multipolys = reduce(lambda x,y: x+y, [list(x) for x in multipolys]) if len(multipolys) > 0 else []
# /usr/local/lib/python3.7/dist-packages/prettymaps/draw.py:109: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   layers = dict(zip(k, v))
# /usr/local/lib/python3.7/dist-packages/descartes/patch.py:65: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   for t in polygon])
# /usr/local/lib/python3.7/dist-packages/prettymaps/draw.py:77: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for shape in shapes:
# /usr/local/lib/python3.7/dist-packages/descartes/patch.py:64: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   [asarray(r)[:, :2] for r in t.interiors])
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-78a7fc371272> in <module>()
#      62     color = '#2F3737',
#      63     rotation = 90,
# ---> 64     fontproperties = fm.FontProperties(fname = '../assets/Permanent_Marker/PermanentMarker-Regular.ttf', size = 35),
#      65 )
#      66 # Draw top text
#
# NameError: name 'fm' is not defined

# %%
# Style parameters
palette = ['#433633', '#FF5E5B']
background_c = '#F2F4CB'
dilate = 100

# Setup figure
fig, ax = plt.subplots(figsize = (10, 10), constrained_layout = True)

# Plot
layers = plot(
    (36.0138857,129.3231836), radius = 5000,
    ax = ax,
    layers = {
        'perimeter': {'circle': False, 'dilate': dilate},
        'streets': {
            'width': {
                'primary': 5,
                'secondary': 4,
                'tertiary': 3,
                'residential': 2,
                'footway': 1,
            },
            'circle': False,
            'dilate': dilate
        },
        'building': {
            'tags': {'building': True},
            'union': False,
            'circle': False,
            'dilate': dilate
        },
        'green': {
            'tags': {
                'landuse': ['grass', 'village_green'],
                'leisure': 'park'
            },
            'circle': False,
            'dilate': dilate
        },
    },
    drawing_kwargs = {
        'background': {'fc': '#F2F4CB', 'ec': '#dadbc1', 'hatch': 'ooo...', 'zorder': -1},
        'perimeter': {'fill': False, 'lw': 0, 'zorder': 0},
        'green': {'fc': '#8BB174', 'ec': '#2F3737', 'hatch_c': '#A7C497', 'hatch': 'ooo...', 'lw': 1, 'zorder': 1},
        'water': {'fc': '#a8e1e6', 'ec': '#2F3737', 'hatch_c': '#9bc3d4', 'hatch': 'ooo...', 'lw': 1, 'zorder': 3},
        'streets': {'fc': '#2F3737', 'ec': '#475657', 'alpha': 1, 'lw': 0, 'zorder': 4},
        'building': {'palette': palette, 'ec': '#2F3737', 'lw': .5, 'zorder': 5},
    },
    osm_credit = {'x': .02, 'y': .01, 'color': '#2F3737'}
)

# Set bounds
xmin, ymin, xmax, ymax = layers['perimeter'].bounds
dx, dy = xmax-xmin, ymax-ymin
ax.set_xlim(xmin-.06*dx, xmax+.06*dx)
ax.set_ylim(ymin-.06*dy, ymax+.06*dy)

# Draw left text
ax.text(
    xmin-.06*dx, ymin+.5*dy,
    'Seoul, Korea',
    color = '#2F3737',
    rotation = 90,
    fontproperties = fm.FontProperties(fname = '../assets/Permanent_Marker/PermanentMarker-Regular.ttf', size = 35),
)
# Draw top text
ax.text(
    xmax-.35*dx, ymax+.02*dy,
    "41° 23′ N, 2° 11′ E",
    color = '#2F3737',
    fontproperties = fm.FontProperties(fname = '../assets/Permanent_Marker/PermanentMarker-Regular.ttf', size = 20),
)

#plt.savefig('../prints/barcelona.png')
#plt.savefig('../prints/barcelona.svg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-26c657c698de> in <module>
#       5
#       6 # Setup figure
# ----> 7 fig, ax = plt.subplots(figsize = (10, 10), constrained_layout = True)
#       8
#       9 # Plot
#
# NameError: name 'plt' is not defined
